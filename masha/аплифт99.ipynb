# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/ВСОС ПО ИИ 2024/train (3).csv')
df
# Out:
#         application_1  cc_1             cc_2   cc_3              cc_4  \
# 0                 NaN   1.0  Representatives  123.0      Первичная ДК
# 1                 NaN   1.0          Offline   43.0          Airports
# 2                 0.0   1.0              Web    2.0               seo
# 3                 0.0   1.0               MB    2.0   One Click Offer
# 4                 0.0   1.0  Representatives  123.0      Первичная ДК
# ...               ...   ...              ...    ...               ...
# 297245            NaN   1.0  Representatives  123.0      Первичная ДК
# 297246            NaN   1.0  Representatives  123.0      Первичная ДК
# 297247            0.0   1.0      Mobile Warm    2.0  TOOS cor clients
# 297248            0.0   1.0  Representatives  123.0      Первичная ДК
# 297249            0.0   1.0      Mobile Warm    2.0  TOOS cor clients
#
#         feature_1  mb_1      cc_5 cc_6  feature_2  ...  cc_21  application_15  \
# ...

# %%
testdf = pd.read_csv('/content/drive/MyDrive/ВСОС ПО ИИ 2024/test (1).csv')
testdf
# Out:
#        application_1  cc_1                            cc_2   cc_3  \
# 0                0.0   1.0                             NaN    NaN
# 1                0.0   1.0                             NaN    NaN
# 2                0.0   1.0                              MB    2.0
# 3                0.0   1.0                 Representatives  123.0
# 4                0.0   1.0                 Representatives  123.0
# ...              ...   ...                             ...    ...
# 74308            NaN   1.0                 Representatives  123.0
# 74309            0.0   1.0                 Representatives  123.0
# 74310            0.0   NaN  PreApprove (Mobile Applicants)    2.0
# 74311            0.0   1.0                 Representatives  123.0
# 74312            0.0   1.0                 Representatives  123.0
#
#                    cc_4  feature_1   mb_1      cc_5 cc_6  feature_2  ...  \
# 0                   NaN          0    6.0       NaN  NaN        0.0  ...
# ...

# %% [markdown]
# ## try 1

# %%
pd.DataFrame({"Total" : df.isna().sum().sort_values(ascending = False),
              "Percentage" : round(df.isna().sum().sort_values(ascending = False) / len(df), 2)}).head(30)
# Out:
#                  Total  Percentage
# feature_23      284741        0.96
# feature_16      278988        0.94
# partner_22      278303        0.94
# bki_20          224048        0.75
# application_12  217768        0.73
# cc_13           202507        0.68
# partner_15      198146        0.67
# cc_14           185053        0.62
# bki_22          179233        0.60
# feature_6       175616        0.59
# bki_40          169674        0.57
# bki_30          169674        0.57
# feature_15      167896        0.56
# feature_8       167896        0.56
# feature_19      158588        0.53
# cc_17           158588        0.53
# cc_21           158588        0.53
# feature_11      157503        0.53
# bki_31          157294        0.53
# bki_11          140961        0.47
# application_4   135978        0.46
# application_3   130354        0.44
# partner_14      128538        0.43
# partner_18      126340        0.43
# feature_14      119894        0.40
# feature_12      119894        0.40
# ...

# %%
print('Total missed data percentage:',
      round(100*df.isna().sum().sum()/(df.shape[0]*df.shape[1]), 2), '%')
# Out:
# Total missed data percentage: 21.28 %

# %%
df = df.drop(columns = ['feature_23', 'feature_16', 'partner_22'])
testdf = testdf.drop(columns = ['feature_23', 'feature_16', 'partner_22'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,4))

sns.countplot(x=df.treatment, ax=ax[0])
sns.countplot(x=df.successful_utilization, ax=ax[1])
# Out:
# <Axes: xlabel='successful_utilization', ylabel='count'>

# %%
df.dtypes[(df.dtypes != 'float64')& (df.dtypes != 'int64')]
# Out:
# cc_2          object
# cc_4          object
# cc_6          object
# retro_date    object
# dtype: object

# %%
df.cc_2.unique()
# Out:
# array(['Representatives', 'Offline', 'Web', 'MB', 'Down-sell',
#        'Mobile Warm', 'PreApprove (Mobile Applicants)', nan,
#        'BAF (Приведи друга)', 'Mobile Cold', 'Other'], dtype=object)

# %%
df.cc_4.unique()
# Out:
# array(['Первичная ДК', 'Airports', 'seo', 'One Click Offer', 'Multitask',
#        'Перевыпуск ДК', 'Cash Loan', 'Other', 'Установка приложения',
#        'SIM', 'Доп.карта ДК', 'TOOS cor clients', 'Другое ДК', 'Heavy',
#        'affilate', 'context', 'CCR Rescore (PA)', 'Heavy xsell', nan,
#        'Страхование', 'Junior ДК', 'Фейк встречи POS',
#        'TOOS afterfilling', 'TOOS other', 'Сразу полные',
#        'LON Rescore (PA)', 'display', 'xsell_income_call_new', 'Rosbank',
#        'COR Clients (PA)', 'pos_tcb_online', 'Инвестиции', 'Light',
#        'POS Rescore (PA)', 'TOOS pos_trigger', 'other int', 'Phone',
#        'SME', 'sms', 'Direct Car Loan', 'Partners', 'web_lk_organic',
#        'кошелек', 'CC Attrition (PA)', 'cpa-bloggers', 'Own Retail',
#        'INV Clients (PA)', 'TOOS cl_trigger', 'mb_toos_pos_xsell',
#        'unpaid', 'native', 'MVNO Clients (PA)', 'xsell_income_chat',
#        'POS Clients (PA)', 'Refinance', 'POS Applicants (PA)', 'new_auth',
# ...

# %%
df.cc_6.unique()
# Out:
# array(['PLT', 'AAR', nan, 'TDC', 'S7C', 'LKC', 'ALC', 'LMC', 'AGC', 'SCB',
#        'NON', 'AAC'], dtype=object)

# %%
df.retro_date = pd.to_datetime(df.retro_date.str.strip('-'))
testdf.retro_date = pd.to_datetime(testdf.retro_date.str.strip('-'))
df.retro_date.isna().sum()
# Out:
# 0

# %%
df.cc_2.isna().sum(),df.cc_4.isna().sum()
# Out:
# (10479, 10482)

# %%
counts = df['cc_6'].value_counts()

# Plot value counts as pie chart
counts.plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
plt.title('Distribution of Categories')
plt.ylabel('')
plt.show()

# %%
df.cc_2 = df.cc_2.fillna('Representatives')
df.cc_4 = df.cc_4.fillna('Первичная ДК')
df.cc_6 = df.cc_6.fillna('PLT')
testdf.cc_2 = testdf.cc_2.fillna('Representatives')
testdf.cc_4 = testdf.cc_4.fillna('Первичная ДК')
testdf.cc_6 = testdf.cc_6.fillna('PLT')

# %%
set(testdf.cc_2.unique()) - set(df.cc_2.unique()),set(testdf.cc_4.unique()) - set(df.cc_4.unique()),set(testdf.cc_6.unique()) - set(df.cc_6.unique())

# %% [markdown]
# значит можно кодировать спокойно targetом

# %%
df[['cc_2','cc_4','cc_6']]

# %%
from sklearn.model_selection import train_test_split

# %%
stratify_cols = pd.concat([df.treatment, df.successful_utilization], axis=1)
X = df.drop(columns = ['successful_utilization'])
y = df['successful_utilization']

# %%
pip install category_encoders

# %%
import category_encoders as ce

# %%
encoder = ce.TargetEncoder(return_df=True)
X = encoder.fit_transform(X, y)
X.dtypes
# Out:
# application_1            float64
# cc_1                     float64
# cc_2                     float64
# cc_3                     float64
# cc_4                     float64
#                        ...
# cc_22                    float64
# partner_24               float64
# application_16             int64
# retro_date        datetime64[ns]
# treatment                  int64
# Length: 148, dtype: object

# %%
testdf = encoder.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=stratify_cols, test_size= 0.1, random_state=1066)

# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.4 MB/s eta 0:00:00
# ...

# %%
pip install scikit-uplift

# %%
from sklift.models import ClassTransformation
from sklift.metrics import uplift_auc_score
from catboost import CatBoostClassifier

# %%
'''from catboost import CatBoostClassifier
from sklift.models import SoloModel, ClassTransformation, TwoModels
from causalml.inference.meta import XGBTRegressor, MLPTRegressor

base_model = CatBoostClassifier(verbose=1000, random_state=42)

solo_model = SoloModel(base_model)

class_trans_model = ClassTransformation(base_model)

#two_models = TwoModels(base_model, base_model)

xgbt_model = XGBTRegressor(random_state=42)

mlpt_model = MLPTRegressor(random_state=42)

for model in [solo_model, class_trans_model]:
    model.fit(X_train, y_train, X_train.treatment)
    uplift_pred = model.predict(X_test)
    auuc = uplift_auc_score(y_test, uplift_pred, X_test.treatment)
    print(model, f'{auuc:.4f}')

# Для causalml моделей:
for model in [xgbt_model, mlpt_model]:
    model.fit(X_train, X_train.treatment, y_train)
    uplift_pred = model.predict(X_test)
    auuc = uplift_auc_score(y_test, uplift_pred, X_test.treatment)
    print(model, f'{auuc:.4f}')'''
# Out:
# Learning rate set to 0.106556
# 0:	learn: 0.6521540	total: 145ms	remaining: 2m 24s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-9ceda1305398> in <cell line: 17>()
#      16
#      17 for model in [solo_model, class_trans_model]:
# ---> 18     model.fit(X_train, y_train, X_train.treatment)
#      19     uplift_pred = model.predict(X_test)
#      20     auuc = uplift_auc_score(y_test, uplift_pred, X_test.treatment)
#
# /usr/local/lib/python3.10/dist-packages/sklift/models/models.py in fit(self, X, y, treatment, estimator_fit_params)
#     127         if estimator_fit_params is None:
#     128             estimator_fit_params = {}
# --> 129         self.estimator.fit(X_mod, y, **estimator_fit_params)
#     130         return self
#     131
#
# ...

# %%
model = CatBoostClassifier(verbose=1000,random_state=42)

# %%
model.fit(
    X=X_train,
    y=y_train,
    treatment=X_train.treatment)
# Out:
# Learning rate set to 0.112052
# 0:	learn: 0.6485643	total: 184ms	remaining: 3m 4s
# 999:	learn: 0.4349269	total: 3m 23s	remaining: 0us
# ClassTransformation(estimator=<catboost.core.CatBoostClassifier object at 0x78acb2bee2c0>)

# %%
testdf
# Out:
#         application_1  cc_1      cc_2   cc_3      cc_4  feature_1  mb_1  \
# 0                 NaN   1.0  0.240108  123.0  0.240108          1  14.0
# 1                 NaN   1.0  0.240108   43.0  0.240108          0   1.0
# 2                 0.0   1.0  0.240108    2.0  0.240108          0   NaN
# 3                 0.0   1.0  0.240108    2.0  0.240108          0  91.0
# 4                 0.0   1.0  0.240108  123.0  0.240108          1   1.0
# ...               ...   ...       ...    ...       ...        ...   ...
# 297245            NaN   1.0  0.240108  123.0  0.240108          1  34.0
# 297246            NaN   1.0  0.240108  123.0  0.240108          1   1.0
# 297247            0.0   1.0  0.240108    2.0  0.240108          0   2.0
# 297248            0.0   1.0  0.240108  123.0  0.240108          1   5.0
# 297249            0.0   1.0  0.240108    2.0  0.240108          0   0.0
#
#             cc_5      cc_6  feature_2  ...  feature_24  cc_21  application_15  \
# ...

# %%
uplift1 = model.predict(testdf)

# %%
uplift1[:subm.shape[0]].shape
# Out:
# (74313,)

# %%
subm['successful_utilization'] = uplift1[:subm.shape[0]]

# %%
subm
# Out:
#        successful_utilization
# 0                   -0.406469
# 1                   -0.846891
# 2                   -0.649510
# 3                   -0.858312
# 4                   -0.775021
# ...                       ...
# 74308               -0.689757
# 74309               -0.231321
# 74310               -0.684826
# 74311               -0.732876
# 74312               -0.551613
#
# [74313 rows x 1 columns]

# %%
subm.to_csv('subm1.csv', sep=',')

# %%
# AUUQ = area under uplift curve
auuc = uplift_auc_score(y_test, uplift1, X_test.treatment)
print(f"Uplift auc score on full data: {auuc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-c56696378c2b> in <cell line: 2>()
#       1 # AUUQ = area under uplift curve
# ----> 2 auuc = uplift_auc_score(y_test, uplift1, X_test.treatment)
#       3 print(f"Uplift auc score on full data: {auuc:.4f}")
#
# /usr/local/lib/python3.10/dist-packages/sklift/metrics/metrics.py in uplift_auc_score(y_true, uplift, treatment)
#     193     """
#     194
# --> 195     check_consistent_length(y_true, uplift, treatment)
#     196     check_is_binary(treatment)
#     197     check_is_binary(y_true)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     455     uniques = np.unique(lengths)
#     456     if len(uniques) > 1:
# --> 457         raise ValueError(
#     458             "Found input variables with inconsistent numbers of samples: %r"
# ...

# %% [markdown]
# ## 2 try

# %%
subm = pd.read_csv('/content/drive/MyDrive/ВСОС ПО ИИ 2024/sample_submission (1).csv',index_col= 'Unnamed: 0')
subm
# Out:
#        successful_utilization
# 0                   -0.635423
# 1                   -0.884969
# 2                    0.000742
# 3                    0.030837
# 4                   -0.355528
# ...                       ...
# 74308                0.640732
# 74309                0.933332
# 74310               -0.085592
# 74311               -0.886694
# 74312                0.490244
#
# [74313 rows x 1 columns]

# %%
pip install causalml

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=stratify_cols, test_size= 0.05, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3dc2d48c74dc> in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=stratify_cols, test_size= 0.05, random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklift.metrics import uplift_auc_score
from catboost import CatBoostRegressor, CatBoostClassifier

# %%
modelcb = CatBoostClassifier(verbose = 0,auto_class_weights='Balanced')
modelcb.fit(X_train,y_train)

# %%
X_test_0 = X_test.copy()
X_test_0['treatment'] = 0
y_pred_0 = modelcb.predict_proba(X_test_0)[:,1]
y_pred_0
# Out:
# array([0.19955544, 0.76472009, 0.66188366, ..., 0.37999095, 0.24351648,
#        0.33961519])

# %%
X_test_0 = X_test.copy()
X_test_0['treatment'] = 0
y_pred_0 = modelcb.predict_proba(X_test_0)[:,1]
X_test_1 = X_test.copy()
X_test_1['treatment'] = 1
y_pred_1 = modelcb.predict_proba(X_test_1)[:,1]
upliftcb = y_pred_1 - y_pred_0

# %%
X_test.treatment.shape,upliftcb.shape,y_test.shape
# Out:
# ((29725,), (29725,), (29725,))

# %%
auuccb = uplift_auc_score(y_test, upliftcb, X_test.treatment)
print(f"Uplift auc score on full data: {auuccb:.4f}")
# Out:
# Uplift auc score on full data: 0.0568

# %%
testdf1 = testdf.copy()
testdf1['treatment'] = 1
y_pred_f1 = modelcb.predict_proba(testdf1)[:,1]
testdf0 = testdf.copy()
testdf0['treatment'] = 0
y_pred_f0 = modelcb.predict_proba(testdf0)[:,1]

# %%
testdf1 = testdf.copy()
testdf1['treatment'] = 1
y_pred_f1 = modelcb.predict_proba(testdf1)[:,1]
testdf0 = testdf.copy()
testdf0['treatment'] = 0
y_pred_f0 = modelcb.predict_proba(testdf0)[:,1]
final_uplift = y_pred_f1 - y_pred_f0
final_uplift = final_uplift * (-1)
final_uplift.shape
# Out:
# (297250,)

# %%
subm['successful_utilization'] = final_uplift[:subm.shape[0]]

# %%
subm.to_csv('subm1.csv', sep=',')

# %%
from causalml.inference.meta import LRSRegressor
from causalml.inference.meta import XGBTRegressor, MLPTRegressor
from causalml.inference.meta import BaseXRegressor
from causalml.inference.meta import BaseRRegressor
from xgboost import XGBRegressor

# %%
#lr = LRSRegressor()
#xg = XGBTRegressor(random_state=42)

nn = MLPTRegressor(hidden_layer_sizes=(10, 10),
                 learning_rate_init=.1,
                 early_stopping=True,
                 random_state=42)

xl = BaseXRegressor(learner=XGBRegressor(random_state=42))
rl = BaseRRegressor(learner=XGBRegressor(random_state=42))

# %%
x_train = X_train.copy()

# %%
x_train['retro_date'] = X_train['retro_date'].astype(int) // 100000000000
x_train.retro_date
# Out:
# 73642     17154720
# 71672     17211744
# 266422    17197056
# 175254    17182368
# 224721    17191872
#             ...
# 211512    17181504
# 93640     17195328
# 224397    17144352
# 188198    17197920
# 35672     17219520
# Name: retro_date, Length: 237800, dtype: int64

# %%
for cols in x_train.columns:
  x_train[cols] = x_train[cols].fillna(x_train[cols].mean())

# %%
model_xl = xl.fit(X = x_train, treatment = tr, y = y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
subm = pd.read_csv('/content/drive/MyDrive/ВСОС ПО ИИ 2024/subm11.csv',index_col = 'Unnamed: 0')
subm
# Out:
#        successful_utilization
# 0                   -0.502902
# 1                   -0.831922
# 2                   -0.400136
# 3                   -0.821805
# 4                   -0.741013
# ...                       ...
# 74308               -0.770271
# 74309               -0.289452
# 74310               -0.677571
# 74311               -0.704171
# 74312               -0.513777
#
# [74313 rows x 1 columns]

# %%
subm['successful_utilization'] = subm['successful_utilization'] *(-1)
subm
# Out:
#        successful_utilization
# 0                    0.502902
# 1                    0.831922
# 2                    0.400136
# 3                    0.821805
# 4                    0.741013
# ...                       ...
# 74308                0.770271
# 74309                0.289452
# 74310                0.677571
# 74311                0.704171
# 74312                0.513777
#
# [74313 rows x 1 columns]

# %%
subm.to_csv('subm3.csv',sep = ',')

# %% [markdown]
# ## TRY BEZ VSEGO

# %%
df = pd.read_csv('/content/drive/MyDrive/ВСОС ПО ИИ 2024/train (3).csv')
df
# Out:
#         application_1  cc_1             cc_2   cc_3              cc_4  \
# 0                 NaN   1.0  Representatives  123.0      Первичная ДК
# 1                 NaN   1.0          Offline   43.0          Airports
# 2                 0.0   1.0              Web    2.0               seo
# 3                 0.0   1.0               MB    2.0   One Click Offer
# 4                 0.0   1.0  Representatives  123.0      Первичная ДК
# ...               ...   ...              ...    ...               ...
# 297245            NaN   1.0  Representatives  123.0      Первичная ДК
# 297246            NaN   1.0  Representatives  123.0      Первичная ДК
# 297247            0.0   1.0      Mobile Warm    2.0  TOOS cor clients
# 297248            0.0   1.0  Representatives  123.0      Первичная ДК
# 297249            0.0   1.0      Mobile Warm    2.0  TOOS cor clients
#
#         feature_1  mb_1      cc_5 cc_6  feature_2  ...  cc_21  application_15  \
# ...

# %%
testdf = pd.read_csv('/content/drive/MyDrive/ВСОС ПО ИИ 2024/test (1).csv')
testdf
# Out:
#        application_1  cc_1                            cc_2   cc_3  \
# 0                0.0   1.0                             NaN    NaN
# 1                0.0   1.0                             NaN    NaN
# 2                0.0   1.0                              MB    2.0
# 3                0.0   1.0                 Representatives  123.0
# 4                0.0   1.0                 Representatives  123.0
# ...              ...   ...                             ...    ...
# 74308            NaN   1.0                 Representatives  123.0
# 74309            0.0   1.0                 Representatives  123.0
# 74310            0.0   NaN  PreApprove (Mobile Applicants)    2.0
# 74311            0.0   1.0                 Representatives  123.0
# 74312            0.0   1.0                 Representatives  123.0
#
#                    cc_4  feature_1   mb_1      cc_5 cc_6  feature_2  ...  \
# 0                   NaN          0    6.0       NaN  NaN        0.0  ...
# ...

# %%
df.retro_date = pd.to_datetime(df.retro_date.str.strip('-')).astype(int) // 100000000000
testdf.retro_date = pd.to_datetime(testdf.retro_date.str.strip('-')).astype(int) // 100000000000

# %%
testdf.cc_6.value_counts().sort_values(ascending = False).index[0]
# Out:
# 'PLT'

# %%
df.cc_2 = df.cc_2.fillna('NAN')
df.cc_4 = df.cc_4.fillna('NAN')
df.cc_6 = df.cc_6.fillna('NAN')
testdf.cc_2 = testdf.cc_2.fillna('NAN')
testdf.cc_4 = testdf.cc_4.fillna('NAN')
testdf.cc_6 = testdf.cc_6.fillna('NAN')

# %%
stratify_cols = pd.concat([df.successful_utilization, df.treatment], axis=1)
X = df.drop(columns = ['successful_utilization'])
y = df['successful_utilization']

# %%
from sklearn.model_selection import train_test_split

# %%
1/237800
# Out:
# 4.205214465937763e-06

# %%
y.unique()
# Out:
# array([0, 1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=stratify_cols, test_size= 0.0001, random_state=42)

# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.1 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostClassifier

# %%
cat_features = ['cc_2','cc_4','cc_6']
modelcb = CatBoostClassifier(verbose = 100, cat_features=cat_features)
modelcb.fit(X_train,y_train)
# Out:
# Learning rate set to 0.117207
# 0:	learn: 0.6466872	total: 790ms	remaining: 13m 9s
# 100:	learn: 0.4809727	total: 55.6s	remaining: 8m 15s
# 200:	learn: 0.4717675	total: 1m 53s	remaining: 7m 31s
# 300:	learn: 0.4655676	total: 2m 51s	remaining: 6m 38s
# 400:	learn: 0.4602462	total: 3m 47s	remaining: 5m 39s
# 500:	learn: 0.4554137	total: 4m 41s	remaining: 4m 39s
# 600:	learn: 0.4511138	total: 5m 37s	remaining: 3m 43s
# 700:	learn: 0.4468219	total: 6m 32s	remaining: 2m 47s
# 800:	learn: 0.4428513	total: 7m 26s	remaining: 1m 50s
# 900:	learn: 0.4390101	total: 8m 22s	remaining: 55.2s
# 999:	learn: 0.4353449	total: 9m 16s	remaining: 0us

# %%
y_w1 = (y == 0).sum() / ((y == 0).sum() + (y == 1).sum())
y_w2 = (y == 1).sum() / ((y == 0).sum() + (y == 1).sum())
print(y_w1,y_w2)
# Out:
# 0.759892346509672 0.240107653490328

# %%
testdf1 = testdf.copy()
testdf1['treatment'] = 1
y_pred_f1 = modelcb.predict_proba(testdf1)[:,1]
testdf0 = testdf.copy()
testdf0['treatment'] = 0
y_pred_f0 = modelcb.predict_proba(testdf0)[:,1]
final_uplift = y_pred_f1 - y_pred_f0
final_uplift.shape
# Out:
# (74313,)

# %%
subm = pd.read_csv('/content/drive/MyDrive/ВСОС ПО ИИ 2024/subm11.csv',index_col = 'Unnamed: 0')
subm
# Out:
#        successful_utilization
# 0                   -0.502902
# 1                   -0.831922
# 2                   -0.400136
# 3                   -0.821805
# 4                   -0.741013
# ...                       ...
# 74308               -0.770271
# 74309               -0.289452
# 74310               -0.677571
# 74311               -0.704171
# 74312               -0.513777
#
# [74313 rows x 1 columns]

# %%
subm['successful_utilization'] = final_uplift[:subm.shape[0]]

# %%
subm.to_csv('subm1.csv', sep=',')
