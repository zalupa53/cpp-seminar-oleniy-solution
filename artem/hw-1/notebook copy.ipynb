# %%
import tqdm
import math
import optuna
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import KBinsDiscretizer
from category_encoders import BinaryEncoder, one_hot
from sklearn.model_selection import train_test_split, StratifiedKFold

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
sample_submission = pd.read_csv('data/sample_submission.csv')

# %%
train_df
# Out:
#        age    country             city  school  faculty  student_id  \
# 0       24     Россия  Санкт-Петербург       9        0     7127004
# 1       21  Казахстан           Астана       5        0     6264436
# 2       17     Россия             Тула       3        0     9056805
# 3       20    Украина             Киев       1        0     8857612
# 4       19     Россия            Пермь       8        0     6422527
# ...    ...        ...              ...     ...      ...         ...
# 95995   21     Россия         Улан-Удэ       5        5     2019496
# 95996   18  Казахстан          Шымкент       9        5     1202270
# 95997   18     Россия      Владивосток      14        5     4114792
# 95998   20    Украина        Запорожье       2        5     5024696
# 95999   25    Украина            Львов       1        5     2264072
#
#                       sociodemographics  test_score  \
# 0      1f63c614a798186e5b5dbca02201a070        21.0
# 1      99fec0c12216abee9eec3bee2138754f        29.0
# 2      f733e24fc7ae975aab7c3e092b1ae96c        89.0
# 3      a2b7795cd58502654754ce03163a1685         2.0
# 4      90519fbbfd457329160e9c1767cb0a86        23.0
# ...                                 ...         ...
# 95995  e065aa14d0861cb2e8c227049bc0b1d3        73.0
# 95996  de6753fb488b87117296d8bef2edc7b3        91.0
# 95997  7ebd9ffcf2f9f0fbe6cfd54917af2098        31.0
# 95998  a2b7795cd58502654754ce03163a1685        45.0
# 95999  664452c22006a9ed7cdf2f74f68f078d        27.0
#
#                          application_id  personal_statement  accepted
# 0      06c4288fba116e49f49d82a16184fca6                 NaN       0.0
# 1      45273a0d372f7f2747afc98bdc63c31a                 NaN       1.0
# 2      773c820049150b6854691b5e7fdcd63f                 NaN       0.0
# 3      d07f757f1b51f8b9189a84298b142794                 NaN       0.0
# 4      269f19b2ef9f46af5012931bfd4acf22                 NaN       0.0
# ...                                 ...                 ...       ...
# 95995  4c33d89befc11bea800221a9d8719549                 NaN       1.0
# 95996  b76e187984d8b80264b4c97fac124f84                 NaN       0.0
# 95997  750e34ebbf17be247c9184149109cbdd                 NaN       1.0
# 95998  0a17ffcb17a2ffd2eb185ac793ed444e                 NaN       1.0
# 95999  275bcbd72200d218ef14508c2c641e44                 NaN       1.0
#
# [96000 rows x 11 columns]

# %%
leaky_cities = []
for city in train_df['city'].unique():
    rw = train_df[train_df['city'] == city]['accepted'].rolling(100).mean()
    if rw.max() >= 0.8 or rw.min() <= 0.2:
        leaky_cities.append(city)
        print(city)
# Out:
# Астана
# Киев
# Харьков
# Минск
# Одесса
# Брест
# Гродно
# Запорожье
# Шымкент
# Актобе
# Витебск
# Гомель
# Львов
# Днепр
# Караганда
# Актау
# Могилёв
# Алматы
# Кривой Рог
# Павлодар

# %%
tmp = train_df[train_df['school'] == 9].sort_values(by='application_id').reset_index(drop=True)
import matplotlib.pyplot as plt
plt.plot(tmp['accepted'].rolling(1000).mean())

# %%
train_df.groupby('city')['accepted'].agg('mean').sort_values()
# Out:
# city
# Астана              0.290012
# Минск               0.292378
# Актобе              0.296784
# Днепр               0.297994
# Алматы              0.299537
# Одесса              0.303721
# Могилёв             0.304020
# Кривой Рог          0.304871
# Львов               0.305474
# Караганда           0.305998
# Киев                0.307559
# Брест               0.307654
# Запорожье           0.308217
# Витебск             0.309206
# Актау               0.311296
# Гродно              0.311966
# Павлодар            0.314067
# Шымкент             0.315407
# Гомель              0.316945
# Харьков             0.320066
# Уфа                 0.323374
# Красноярск          0.337963
# Челябинск           0.341463
# Томск               0.343548
# Нижний Новгород     0.344464
# Киров               0.347334
# Калининград         0.347443
# Санкт-Петербург     0.348199
# Воронеж             0.348797
# Астрахань           0.349418
# Самара              0.350087
# Тольятти            0.352851
# Тула                0.353234
# Владивосток         0.353571
# Саратов             0.354201
# Ярославль           0.354575
# Чебоксары           0.355240
# Москва              0.357022
# Ульяновск           0.357488
# Пенза               0.357827
# Курск               0.360140
# Екатеринбург        0.361983
# Кемерово            0.362890
# Казань              0.363790
# Барнаул             0.365385
# Новокузнецк         0.365416
# Краснодар           0.365891
# Волгоград           0.370000
# Омск                0.373451
# Рязань              0.373737
# Улан-Удэ            0.374787
# Тюмень              0.375776
# Липецк              0.376026
# Оренбург            0.376119
# Пермь               0.379032
# Иркутск             0.379661
# Новосибирск         0.379768
# Ижевск              0.380875
# Ростов-на-Дону      0.381599
# Набережные Челны    0.382253
# Name: accepted, dtype: float64

# %%
test_df
# Out:
#            ID  age    country             city  school  faculty  student_id  \
# 0       96000   21     Россия  Санкт-Петербург       9        0     4428545
# 1       96001   22  Казахстан           Астана       5        0     4828171
# 2       96002   23     Россия             Тула       3        0     6305415
# 3       96003   17    Украина             Киев       1        0     5175385
# 4       96004   24     Россия            Пермь       8        0     1809466
# ...       ...  ...        ...              ...     ...      ...         ...
# 23995  119995   24    Украина        Запорожье       9        5     4222406
# 23996  119996   17    Украина        Запорожье      12        5     4382550
# 23997  119997   17  Казахстан           Алматы       2        5     2780558
# 23998  119998   18  Казахстан           Астана       5        5     1773219
# 23999  119999   20    Украина       Кривой Рог       6        5     4221424
#
#                       sociodemographics  test_score  \
# 0      adcb62fdc1121af780dc4138486cc7e3        63.0
# 1      05ec3873d1ced60fb3d4327bfd368e00        62.0
# 2      1533b17f2c49fec036550ee67955b0a6        17.0
# 3      f1eef626c29a481a5527d242ae5516a8        25.0
# 4      67086df93882a3958b6163a60d0bd6b5        64.0
# ...                                 ...         ...
# 23995  c35fb088b2e889aeb1f99fc9d21292a5        38.0
# 23996  bfbca9e6c1e7d0b3e670af72336b6e60        90.0
# 23997  56b4da4b9f916a54be39f26757c8ce14        78.0
# 23998  ce33a4a84820e71f4f0b507d574c4146        90.0
# 23999  a2b7795cd58502654754ce03163a1685        37.0
#
#                          application_id  personal_statement
# 0      700db6161a195963a89ee91a11bc6449                 NaN
# 1      c818a649e468d97325813b877fb7f308                 NaN
# 2      0cc80bc0aa8531794601980c4c2f0fb7                 NaN
# 3      ed05d43a670eea5a75662cc82d3a4b7d                 NaN
# 4      7b3e7852822d85f1de686caeb0c6307d                 NaN
# ...                                 ...                 ...
# 23995  566ef31470ee65f6f9ab087dedee4f62                 NaN
# 23996  0f67dbe83cb72c6b8b3bbb89c9cc6d02                 NaN
# 23997  e8e86ee3af0ba2f4408c08a8f431b284                 NaN
# 23998  444d9437a6e57a722715af2feab9ce82                 NaN
# 23999  7f51f64da757a40ec19c201ae44dd79d                 NaN
#
# [24000 rows x 11 columns]

# %%
# PASHALKO #1
((pd.concat([train_df, test_df], axis=0).groupby(['sociodemographics', 'application_id'])['accepted'].agg('count') == 2) * (pd.concat([train_df, test_df], axis=0).groupby(['sociodemographics', 'application_id'])['accepted'].agg('sum')) == (pd.concat([train_df, test_df], axis=0).groupby(['sociodemographics', 'application_id'])['accepted'].agg('count') == 2).astype('float')).all()
# Out:
# True

# %%
# PASHALKO #2
train_df[train_df['test_score'] % 1 > 0].groupby(['student_id', 'application_id'])['accepted'].agg('max').min()
# Out:
# 1.0

# %%
# train_df['application_id'] = train_df['application_id'].apply(lambda x: math.log(int(x, 16), 2)).astype(float)
# test_df['application_id'] = test_df['application_id'].apply(lambda x: math.log(int(x, 16), 2)).astype(float)

# PASHALKO #3
train_df['application_id'] = train_df['application_id'].apply(lambda x: int(x, 16))
test_df['application_id'] = test_df['application_id'].apply(lambda x: int(x, 16))

# %%
# PASHALKO #4
train_df['student_id_%'] = train_df['student_id'] % 100
test_df['student_id_%'] = test_df['student_id'] % 100

# %%
train_df['application_id_%'] = train_df['application_id'] % 250
test_df['application_id_%'] = test_df['application_id'] % 250

# %%
# train_df['cool_feature'] = train_df.groupby('faculty').cumcount() / (train_df.groupby('faculty').transform('size'))  ########################################
# test_df['cool_feature'] = test_df.groupby('faculty').cumcount() / (test_df.groupby('faculty').transform('size'))     ########################################

# %%
# PASHALKO #6
train_df['cool_feature'] = train_df.groupby('faculty').cumcount() / (train_df.groupby('faculty').transform('size'))
discretizer = KBinsDiscretizer(n_bins=40, encode='ordinal', strategy='uniform')
train_df['cool_feature'] = discretizer.fit_transform(train_df[['cool_feature']])[:, 0]
mapl = train_df.groupby('cool_feature')['accepted'].mean()
train_df['cool_feature'] = train_df['cool_feature'].apply(lambda x: mapl[x]) >= 0.7

test_df['cool_feature'] = test_df.groupby('faculty').cumcount() / (test_df.groupby('faculty').transform('size'))
test_df['cool_feature'] = discretizer.transform(test_df[['cool_feature']])[:, 0]
test_df['cool_feature'] = test_df['cool_feature'].apply(lambda x: mapl[x]) >= 0.7

# %%
train_df = train_df.drop(columns=['personal_statement'], axis=1)
test_df = test_df.drop(columns=['personal_statement'], axis=1)

# %%
# PASHALKO #5
binenc = BinaryEncoder(cols=['city', 'school', 'sociodemographics'])
ohenc = one_hot.OneHotEncoder(cols=['country', 'faculty', 'student_id_%', 'application_id_%'])
processed_train_df = ohenc.fit_transform(binenc.fit_transform(train_df)).sample(frac=1, random_state=42)

# %%
processed_train_df
# Out:
#        age  country_1  country_2  country_3  country_4  city_0  city_1  \
# 83250   23          0          0          0          1       0       0
# 71978   18          0          0          0          1       0       1
# 47489   19          1          0          0          0       0       0
# 94910   20          1          0          0          0       1       0
# 18844   18          0          0          1          0       0       1
# ...    ...        ...        ...        ...        ...     ...     ...
# 6265    23          0          0          0          1       0       1
# 54886   22          0          1          0          0       1       0
# 76820   17          1          0          0          0       1       1
# 860     20          0          0          0          1       0       0
# 15795   19          0          0          1          0       0       1
#
#        city_2  city_3  city_4  ...  application_id_%_242  \
# 83250       1       1       1  ...                     0
# 71978       0       1       0  ...                     0
# 47489       1       0       1  ...                     0
# 94910       0       1       1  ...                     0
# 18844       0       0       0  ...                     0
# ...       ...     ...     ...  ...                   ...
# 6265        0       1       1  ...                     0
# 54886       0       0       1  ...                     0
# 76820       1       0       1  ...                     0
# 860         1       1       1  ...                     0
# 15795       0       1       1  ...                     0
#
#        application_id_%_243  application_id_%_244  application_id_%_245  \
# 83250                     0                     0                     0
# 71978                     0                     0                     0
# 47489                     0                     0                     0
# 94910                     0                     0                     0
# 18844                     0                     0                     0
# ...                     ...                   ...                   ...
# 6265                      0                     0                     0
# 54886                     0                     0                     0
# 76820                     0                     0                     0
# 860                       0                     0                     0
# 15795                     0                     0                     0
#
#        application_id_%_246  application_id_%_247  application_id_%_248  \
# 83250                     0                     0                     0
# 71978                     0                     0                     0
# 47489                     0                     0                     0
# 94910                     0                     0                     0
# 18844                     0                     0                     0
# ...                     ...                   ...                   ...
# 6265                      0                     0                     0
# 54886                     0                     1                     0
# 76820                     0                     0                     0
# 860                       0                     0                     0
# 15795                     0                     0                     0
#
#        application_id_%_249  application_id_%_250  cool_feature
# 83250                     1                     0         False
# 71978                     0                     0         False
# 47489                     0                     0          True
# 94910                     0                     0          True
# 18844                     0                     0         False
# ...                     ...                   ...           ...
# 6265                      0                     0         False
# 54886                     0                     0         False
# 76820                     0                     1         False
# 860                       0                     0         False
# 15795                     0                     0          True
#
# [96000 rows x 384 columns]

# %%
class Ensemble:
    def __init__(self, models):
        self.models = models
    
    def predict(self, X):
        predictions_weighted_sum = np.full(len(X), 0.0)
        weights_sum = 0
        for model, weight in self.models:
            predictions_weighted_sum += model.predict_proba(X)[:, 1] * weight
            weights_sum += weight
        return predictions_weighted_sum / weights_sum

# %%
main_model = Ensemble([
    [CatBoostClassifier(iterations=3000, verbose=0).fit(processed_train_df.drop(columns=['accepted'], axis=1), processed_train_df['accepted']), 1.0], 
])

# %%
test_df['accepted'] = np.full(len(test_df), 0)
sample_submission['accepted'] = main_model.predict(ohenc.transform(binenc.transform(test_df.drop(columns=['ID'], axis=1))).drop(columns=['accepted'], axis=1))

# %%
# # PASHALKO #6
# train_df['cool_feature'] = train_df.groupby('faculty').cumcount() / (train_df.groupby('faculty').transform('size'))
# discretizer = KBinsDiscretizer(n_bins=500, encode='ordinal', strategy='uniform')
# train_df['cool_feature'] = discretizer.fit_transform(train_df[['cool_feature']])[:, 0]
# mapl = train_df.groupby('cool_feature')['accepted'].mean()
# train_df['cool_feature'] = train_df['cool_feature'].apply(lambda x: mapl[x])

# test_df['cool_feature'] = test_df.groupby('faculty').cumcount() / (test_df.groupby('faculty').transform('size'))
# test_df['cool_feature'] = discretizer.transform(test_df[['cool_feature']])[:, 0]
# test_df['cool_feature'] = test_df['cool_feature'].apply(lambda x: mapl[x])

# %%
# socdem_pashalko_proba = train_df[train_df['cool_feature'] >= 0.7].groupby('sociodemographics')['accepted'].mean()
# for i in tqdm.tqdm(test_df.index):
#     general_proba = sample_submission['accepted'][i]
#     pashalko_proba = test_df.loc[[i], 'cool_feature']
#     if pashalko_proba.iloc[0] >= 0.7:
#         sample_submission['accepted'][i] = (general_proba * 0.9 + socdem_pashalko_proba[test_df['sociodemographics'][i]] * 0.1) / (0.9 + 0.1)

# %%
for i in tqdm.tqdm(test_df.index):
    aplid = test_df['application_id'][i]
    socdem = test_df['sociodemographics'][i]
    trrel = train_df[(train_df['application_id'] == aplid) & (train_df['sociodemographics'] == socdem)]
    if len(trrel) == 1:
        if trrel['accepted'].iloc[0] == 0:
            sample_submission['accepted'][i] = 1.0
            continue
        elif trrel['accepted'].iloc[0] == 1:
            sample_submission['accepted'][i] = 0.0
            continue
    elif len(trrel) == 0:
        tsrel = test_df[(test_df['application_id'] == aplid) & (test_df['sociodemographics'] == socdem)]
        if len(tsrel) == 2:
            pp0 = sample_submission['accepted'][tsrel.index[0]]
            pp1 = sample_submission['accepted'][tsrel.index[1]]
            sample_submission['accepted'][tsrel.index[0]] = pp0 - ((pp0 + pp1 - 1) / 2)
            sample_submission['accepted'][tsrel.index[1]] = pp1 - ((pp0 + pp1 - 1) / 2)
            continue
# Out:
# 100%|██████████| 24000/24000 [03:44<00:00, 107.10it/s]

# %%
sample_submission['accepted'][test_df['test_score'] % 1 > 0] = 1

# %%
sample_submission.to_csv('submission.csv', index=False)
